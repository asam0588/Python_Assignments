# %% [markdown]
# Q1. Why do we call Python as a general purpose and high-level programming language?
# A: Python is not domain specific and can be used for web-development, application development, scientific research etc.so it is
#     general purpose.
#     High-level : Because it has a user friendly programming context.
#
# Q2. Why is Python called a dynamically typed language?
# A:  Because we need not declare the type of variable while assigning a value to a variable in Python
#
# Q3. List some pros and cons of Python programming language?
# A: Pros:
#         -Python is easy to read, easy to understand, and easy to write.
#         -It integrates with other programming languages like C, C++, and Java.
#         -Python supports extensive libraries for differnt features.
#         -Python is platform-independent means you can write code once and
#             run it anywhere.
#     Cons:
#         -Python is not suitable for developing mobile applications and games.
#         -Python works with the interpreter. That's why it is slower than other
#             programming languages like C and C++
#
# Q4. In what all domains can we use Python?
# A:
#     -GUI applications.
#     -Web applications.
#     -Scrape data from websites
#     -Analyze Data.
#     -System administration utilities.
#     -Game Development.
#     -Data Science.
#     -Connect to database systems.
#     -Handle Big Data & perform mathematics.
#
#
# Q5. What are variable and how can we declare them?
# A:  Variables are named locations that are used to store information in
#     memory. The names we choose for variables and functions are commonly known as Identifiers.
#     -Python has no command for declaring a variable. A variable is created the moment you first assign a value to it.
#
# Q6. How can we take an input from the user in Python?
# A:input ()function takes the input from the user
#
# Q7. What is the default datatype of the value that has been taken as an input using input() function?
# A: Sting  <type ‘str’>
#
# Q8. What is type casting?
# A: Changing the datatype of one variable to another, float to int, int to string etc.
#
# Q9. Can we take more than one input from the user using single input() function? If yes, how? If no, why?
# A: No, input() function does not allow the user to provide values separated by a new line.
#  Whenever the user presses the enter key, the input function reads information provided by the user and stops execution.
#
# Q10. What are keywords?
# A: Keywords are reserved words in a programming language whijch cannot be used as variable or function names.
#
# Q11. Can we use keywords as a variable? Support your answer with reason.
# A:  No keywords can't be used as a variable it's because keywords have predefined meanings.
#     If we try to use a keyword as variable we get an error.
#
# Q12. What is indentation? What's the use of indentaion in Python?
# A: Indentation refers to the spaces at the beginning of a code line.Python indentation is a way of telling a
#     Python interpreter that the group of statements belongs to a particular block of code.
#
# Q13. How can we throw some output in Python?
# A: Using the print() function we can show output in Python.
#
# Q14. What are operators in Python?
# A: Operators are special symbols in Python that carry out arithmetic or logical computation.
#
# Q15. What is difference between / and // operators?
# A: / is division (float) and // for floor division.floor division // rounds the result down to the nearest whole number.
#
# Q16. Write a code that gives following as an output.
# A: print("iNeuroniNeuroniNeuroniNeuron")
#
# Q17. Write a code to take a number as an input from the user and check if the number is odd or even.
# A:
#     number = int(input('Enter a number of your choice: '))
#
#     if (number % 2) == 0:
#         print('The number you entered is even')
#     else:
#         print('The number you entered is odd')
#
# Q18. What are boolean operator?
# A: Boolean is type of value that can be either True or False.Logical operators AND, OR and NOT can be used are
#    used to compare values. They evaluate expressions down to Boolean values, returning either True or False.
#
# Q19. What will the output of the following?
# ```
# 1 or 0
#
# 0 and 0
#
# True and False and True
#
# 1 or 0 or 0
# ``````````
# A: 1 or 0 : 1
#
# 0 and 0 : 0
#
# True and False and True: False
#
# 1 or 0 or 0: 1
#
# Q20. What are conditional statements in Python?
# A: Conditional statements control behavior and determine whether or not
#    pieces of code can run.
#
# Q21. What is use of 'if', 'elif' and 'else' keywords?
# A: Use IF to specify a block of code to be executed, if a specified condition is true.
# Syntax: if <expression> :
#          #statement
#     Use ELIF to specify a new condition to test, if the first condition is false.
# Syntax:
#     if boolean-expression:
#      #statements
#     elif boolean-expression:
#      #statements
#     elif boolean-expression:
#      #statements
#     elif boolean-expression:
#       #statement
#     else:
#     #statements
#      Use IF-ELSE to specify a block of code to be executed, if the same condition is true and if condition is false,
#         it executes other block of code.
# Syntax: if boolean-expression:
#           #statements
#         else:
#           #statements
#
# Q22. Write a code to take the age of person as an input and if age >= 18 display "I can vote". If age is < 18 display "I can't vote".
# A:
#
# age = int(input('Enter your age: '))
#
# if age >= 18:
#     print("I can vote")
# else:
#     print("I can't vote")
#
#
# Q23. Write a code that displays the sum of all the even numbers from the given list.
# ```
# numbers = [12, 75, 150, 180, 145, 525, 50]
# ```
# A:
# numbers = [12, 75, 150, 180, 145, 525, 50]
# sum = 0
# for i in numbers:
#     if i % 2 == 0:
#      sum = sum + i
# print(sum)
#
# Q24. Write a code to take 3 numbers as an input from the user and display the greatest no as output.
# A:
# num_1 = int(input('Enter the first number: '))
# num_2 = int(input('Enter the second number: '))
# num_3 = int(input('Enter the third number: '))
#
# if ((num_1 > num_2) and (num_1 > num_3)):
#     print("The greatest number is: ", num_1)
# elif ((num_2 > num_1) and (num_2 > num_3)):
#     print("The greatest number is: ", num_2)
# else:
#     print("The greatest number is: ", num_3)
#
#
# Q25. Write a program to display only those numbers from a list that satisfy the following conditions
#
# - The number must be divisible by five
#
# - If the number is greater than 150, then skip it and move to the next number
#
# - If the number is greater than 500, then stop the loop
# ```
# numbers = [12, 75, 150, 180, 145, 525, 50]
# ```
# A:
# numbers = [12, 75, 150, 180, 145, 525, 50]
# for i in numbers:
#     if i > 150:
#         if i > 500:
#             break
#         continue
#     if i % 5 == 0:
#      print(i)
